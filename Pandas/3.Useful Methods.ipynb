# %% [markdown]
# # Useful Methods

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tips.csv')

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %% [markdown]
# ## .apply()
#
# This method is use to apply one function to the column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
def first_four(num):
    return str(num)[:4]

# %%
df['CC Number'][0]
# Out:
# 3560325168603410

# %%
first_four(3560325168603410)
# Out:
# '3560'

# %%
# apply first four to all cc number and create new column first_four

# %%
df['first_four'] = df['CC Number'].apply(first_four)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID first_four
# 0  Christy Cunningham  3560325168603410    Sun2959       3560
# 1      Douglas Tucker  4478071379779230    Sun4608       4478
# 2      Travis Walters  6011812112971322    Sun4458       6011

# %%
df['price_per_person'].mean()
# Out:
# 7.888196721311474

# %%
def star(price):
    if price < 5:
        return '*'
    elif price >= 5 and price < 7.88:
        return '**'
    else:
        return '***'

# %%
df['Star'] = df['price_per_person'].apply(star)

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID first_four Star
# 0  Christy Cunningham  3560325168603410    Sun2959       3560  ***
# 1      Douglas Tucker  4478071379779230    Sun4608       4478    *
# 2      Travis Walters  6011812112971322    Sun4458       6011   **
# 3    Nathaniel Harris  4676137647685994    Sun5260       4676  ***
# 4        Tonya Carter  4832732618637221    Sun2251       4832   **

# %% [markdown]
# apply method with lambda

# %%
# This is normal function 
def simple(num):
    return num*2

# %%
# This is lambda function
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda bill:bill*0.18)
# Out:
# 0      3.0582
# 1      1.8612
# 2      3.7818
# 3      4.2624
# 4      4.4262
#         ...
# 239    5.2254
# 240    4.8924
# 241    4.0806
# 242    3.2076
# 243    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# ## apply use for multiple columns
#
# Note, there are several ways to do this:
#
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID first_four Star
# 0  Christy Cunningham  3560325168603410    Sun2959       3560  ***
# 1      Douglas Tucker  4478071379779230    Sun4608       4478    *
# 2      Travis Walters  6011812112971322    Sun4458       6011   **
# 3    Nathaniel Harris  4676137647685994    Sun5260       4676  ***
# 4        Tonya Carter  4832732618637221    Sun2251       4832   **

# %%
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
#using lambda we can apply method so many columns
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID first_four Star Tip Quality
# 0  Christy Cunningham  3560325168603410    Sun2959       3560  ***       Other
# 1      Douglas Tucker  4478071379779230    Sun4608       4478    *       Other
# 2      Travis Walters  6011812112971322    Sun4458       6011   **       Other

# %%
df.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID first_four Star Tip Quality
# 241       Keith Wong  6011891618747196    Sat3880       6011  ***       Other
# 242     Dennis Dixon     4375220550950      Sat17       4375  ***       Other
# 243  Michelle Hardin  3511451626698139    Thur672       3511  ***       Other

# %%
# we can also use vectorize
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID first_four Star Tip Quality
# 241       Keith Wong  6011891618747196    Sat3880       6011  ***       Other
# 242     Dennis Dixon     4375220550950      Sat17       4375  ***       Other
# 243  Michelle Hardin  3511451626698139    Thur672       3511  ***       Other

# %% [markdown]
# ## statistical summaries

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# ## sort_values()

# %%
df.sort_values('price_per_person').head(3)
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 92        5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 16       10.33  1.67  Female     No  Sun  Dinner     3              3.44
#
#           Payer Name         CC Number Payment ID first_four Star Tip Quality
# 92      Leah Ramirez  3508911676966392    Fri3780       3508    *       Other
# 67     Tiffany Brock  4359488526995267    Sat3455       4359    *    Generous
# 16  Elizabeth Foster  4240025044626033    Sun9715       4240    *       Other

# %%
df.sort_values(['price_per_person','tip']).tail(3)
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 179       34.63   3.55  Male    Yes  Sun  Dinner     2             17.32
# 184       40.55   3.00  Male    Yes  Sun  Dinner     2             20.27
#
#         Payer Name         CC Number Payment ID first_four Star Tip Quality
# 170  Gregory Clark  5473850968388236    Sat1954       5473  ***       Other
# 179   Brian Bailey   346656312114848    Sun9851       3466  ***       Other
# 184    Stephen Cox  3547798222044029    Sun5140       3547  ***       Other

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df[['price_per_person','tip']].corr()
# Out:
#                   price_per_person       tip
# price_per_person          1.000000  0.347405
# tip                       0.347405  1.000000

# %% [markdown]
# ## idxmin and idxmax
#
# idxmax = find the location of max number
#
# idxmin = find the loction of min number

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID first_four Star Tip Quality
# 0  Christy Cunningham  3560325168603410    Sun2959       3560  ***       Other
# 1      Douglas Tucker  4478071379779230    Sun4608       4478    *       Other
# 2      Travis Walters  6011812112971322    Sun4458       6011   **       Other

# %%
df['total_bill'].min()
# Out:
# 3.07

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %% [markdown]
# ## value_counts
#
# Get a count per category

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# ## replace

# %%
#Quickly replace values with another one.
dff =df['Tip Quality'].replace(to_replace='Other',value='Ok')

# %%
dff.head(3)
# Out:
# 0    Ok
# 1    Ok
# 2    Ok
# Name: Tip Quality, dtype: object

# %% [markdown]
# ## unique
#
# Find the unique number

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df['size'].nunique()
# Out:
# 6

# %% [markdown]
# ## map
#
# map the value with dif name

# %%
my_map = {'Dinner':'D','Lunch':'L'}

# %%
df['time'].map(my_map).tail(3)
# Out:
# 241    D
# 242    D
# 243    D
# Name: time, dtype: object

# %% [markdown]
# ## Duplicates
#
# Return the true for the second time value occurred

# %%
df.duplicated().tail(3)
# Out:
# 241    False
# 242    False
# 243    False
# dtype: bool

# %% [markdown]
# ## between
#
# find between value which we given

# %%
df['total_bill'].between(10,20,inclusive=True).head(3)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_27392/1199090320.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df['total_bill'].between(10,20,inclusive=True).head(3)
# 0     True
# 1     True
# 2    False
# Name: total_bill, dtype: bool

# %%
df[df['total_bill'].between(10,20,inclusive=True)].tail(3)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_27392/3019467720.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df[df['total_bill'].between(10,20,inclusive=True)].tail(3)
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID first_four Star Tip Quality
# 236    Matthew Myers  3543676378973965    Sat5032       3543   **       Other
# 242     Dennis Dixon     4375220550950      Sat17       4375  ***       Other
# 243  Michelle Hardin  3511451626698139    Thur672       3511  ***       Other

# %% [markdown]
# ## sample
#
# Find any random value of sample

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 132       11.17  1.50  Female     No  Thur   Lunch     2              5.58
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2             14.48
# 141       34.30  6.70    Male     No  Thur   Lunch     6              5.72
# 44        30.40  5.60    Male     No   Sun  Dinner     4              7.60
# 20        17.92  4.08    Male     No   Sat  Dinner     2              8.96
#
#           Payer Name         CC Number Payment ID first_four Star Tip Quality
# 132  Taylor Gonzalez  6011990685390011   Thur7783       6011   **       Other
# 90      Daniel Mason  3597456900644078    Fri4175       3597  ***       Other
# 141   Steven Carlson  3526515703718508   Thur1025       3526   **       Other
# 44       Todd Cooper      503846761263    Sun2274       5038   **       Other
# 20       Thomas Rice  4403296224639756    Sat1709       4403  ***       Other

# %%
#find any frac% sample from dataset
df.sample(frac=0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 124       12.48  2.52  Female     No  Thur   Lunch     2              6.24
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 64        17.59  2.64    Male     No   Sat  Dinner     3              5.86
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2              7.84
# 151       13.13  2.00    Male     No   Sun  Dinner     2              6.56
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4              9.50
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2             12.64
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2              8.00
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 57        26.41  1.50  Female     No   Sat  Dinner     2             13.20
# 139       13.16  2.75  Female     No  Thur   Lunch     2              6.58
# 143       27.05  5.00  Female     No  Thur   Lunch     6              4.51
# 25        17.81  2.34    Male     No   Sat  Dinner     4              4.45
# 114       25.71  4.00  Female     No   Sun  Dinner     3              8.57
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2              8.16
# 97        12.03  1.50    Male    Yes   Fri  Dinner     2              6.02
# 47        32.40  6.00    Male     No   Sun  Dinner     4              8.10
# 180       34.65  3.68    Male    Yes   Sun  Dinner     4              8.66
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5              5.63
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2              6.37
# 127       14.52  2.00  Female     No  Thur   Lunch     2              7.26
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
#
#                 Payer Name         CC Number Payment ID first_four Star  \
# 124            Jordan Diaz  4472778228206399    Thur208       4472   **
# 145              Amy Young     4285454264477   Thur9331       4285    *
# 64         Michael Johnson  2222114458088108    Sat1667       2222   **
# 190           Riley Barnes   180053549128800    Sun5104       1800   **
# 151           Jason Arnold  3571825125296106    Sun2127       3571   **
# 56   James Christensen DDS   349793629453226    Sat8903       3497  ***
# 73            Julie Holmes  5418689346409571    Sat6065       5418  ***
# 138          Jason Burgess  3561461821942363   Thur2710       3561  ***
# 9            Jerome Abbott  3532124519049786    Sun3775       3532   **
# 57            Melody Simon  4745394421258160    Sat8980       4745  ***
# 139          Lindsey Meyer      676239597203   Thur6245       6762   **
# 143           Regina Jones     4311048695487   Thur6179       4311    *
# 25          Robert Perkins    30502930499388     Sat907       3050    *
# 114            Katie Smith  5400160161311292    Sun6492       5400  ***
# 93          Natalie Nguyen  5181236182893396    Fri6963       5181  ***
# 97            Eric Herrera      580116092652    Fri9268       5801   **
# 47            James Barnes  3552002592874186    Sun9677       3552  ***
# 180       James Hebert DDS      676168737648    Sun7544       6761  ***
# 8          Joseph Mcdonald  3522866365840377    Sun6820       3522   **
# 216      Shawn Barnett PhD     4590982568244    Sat7320       4590   **
# 201          Abigail Parks  3586645396220590   Thur2544       3586   **
# 127        Jessica Simmons   213102478792200   Thur1512       2131   **
# 238         Kimberly Crane      676184013727    Sat9777       6761  ***
# 229       Jennifer Russell     4793003293608    Sat3943       4793  ***
#
#     Tip Quality
# 124       Other
# 145       Other
# 64        Other
# 190       Other
# 151       Other
# 56        Other
# 73        Other
# 138       Other
# 9         Other
# 57        Other
# 139       Other
# 143       Other
# 25        Other
# 114       Other
# 93     Generous
# 97        Other
# 47        Other
# 180       Other
# 8         Other
# 216       Other
# 201       Other
# 127       Other
# 238       Other
# 229       Other

# %% [markdown]
# ## nlargest and nsmallest
#
# Find give n largest or smallest number

# %%
df.nlargest(10,'price_per_person')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 179       34.63   3.55    Male    Yes   Sun  Dinner     2             17.32
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 175       32.90   3.11    Male    Yes   Sun  Dinner     2             16.45
# 237       32.83   1.17    Male    Yes   Sat  Dinner     2             16.42
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2             16.34
# 173       31.85   3.18    Male    Yes   Sun  Dinner     2             15.92
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 90        28.97   3.00    Male    Yes   Fri  Dinner     2             14.48
#
#           Payer Name         CC Number Payment ID first_four Star Tip Quality
# 184      Stephen Cox  3547798222044029    Sun5140       3547  ***       Other
# 179     Brian Bailey   346656312114848    Sun9851       3466  ***       Other
# 170    Gregory Clark  5473850968388236    Sat1954       5473  ***       Other
# 175  Nathan Reynolds   370307040837149    Sun5109       3703  ***       Other
# 237     Thomas Brown  4284722681265508    Sat2929       4284  ***       Other
# 83     Daniel Murphy  5356177501009133   Thur8801       5356  ***       Other
# 173      Scott Perez  3577115550328507    Sun9335       3577  ***       Other
# 182     Jose Parsons  4112207559459910    Sun2337       4112  ***       Other
# 102    Heather Cohen   379771118886604    Sat6240       3797  ***       Other
# 90      Daniel Mason  3597456900644078    Fri4175       3597  ***       Other

# %%
df.nsmallest(10,'price_per_person')
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51  2.00    Male     No  Thur   Lunch     2              3.76
# 195        7.56  1.44    Male     No  Thur   Lunch     2              3.78
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2              3.87
# 159       16.49  2.00    Male     No   Sun  Dinner     4              4.12
# 185       20.69  5.00    Male     No   Sun  Dinner     5              4.14
#
#            Payer Name         CC Number Payment ID first_four Star Tip Quality
# 92       Leah Ramirez  3508911676966392    Fri3780       3508    *       Other
# 67      Tiffany Brock  4359488526995267    Sat3455       4359    *    Generous
# 16   Elizabeth Foster  4240025044626033    Sun9715       4240    *       Other
# 1      Douglas Tucker  4478071379779230    Sun4608       4478    *       Other
# 172       Larry White    30432617123103    Sun9209       3043    *    Generous
# 149    Daniel Robbins  4823139288341889   Thur6321       4823    *    Generous
# 195     Michael White  4865390263095532    Thur697       4865    *       Other
# 218   Nicholas Archer   340517153733524    Sat4772       3405    *       Other
# 159  Christopher Soto    30501814271434    Sun1781       3050    *       Other
# 185     Joseph Howell    30362407455623    Sun5842       3036    *       Other
